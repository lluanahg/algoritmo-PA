# %% [markdown]
# <a href="https://colab.research.google.com/github/lluanahg/algoritmo-PA/blob/main/le_15_09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# EXERCICIOS;

# EXERCÍCIO 1 - LISTAS
frutas = ["maçã", "banana", "laranja", "morango"]
print(frutas)
# Out:
# ['maçã', 'banana', 'laranja', 'morango']

# %%
# EXERCÍCIO 2 - LISTAS
nomes = ["Rebeca", "Guilherme", "Melissa", "Kyara"]
print("Primeiro:", nomes[0])
print("Segundo:", nomes[1])
print("Último:", nomes[-1])
# Out:
# Primeiro: Rebeca
# Segundo: Guilherme
# Último: Kyara

# %%
# EXERCÍCIO 3 - LISTAS
cores = ["vermelho", "azul", "verde"]
cores[1] = "amarelo"
print(cores)
# Out:
# ['vermelho', 'amarelo', 'verde']

# %%
# EXERCÍCIO 4 - LISTAS
alunos = ["Nicolas", "Wendel", "Pyetra"]
alunos.append("Petros")
print(alunos)
# Out:
# ['Nicolas', 'Wendel', 'Pyetra', 'Petros']

# %%
# EXERCÍCIO 5 - LISTAS
animais = ["cachorro", "gato", "coelho", "passarinho"]
animais.remove("coelho")
print(animais)
# Out:
# ['cachorro', 'gato', 'passarinho']

# %%
# EXERCÍCIO 6 - TUPLAS (1)
meses = ("Janeiro", "Fevereiro", "Março", "Abril")
print(meses)
# Out:
# ('Janeiro', 'Fevereiro', 'Março', 'Abril')

# %%
# EXERCÍCIO 7 - TUPLAS (2)
numeros = (10, 20, 30, 40, 50)
print("Primeiro:", numeros[0])
print("Terceiro:", numeros[2])
print("Último:", numeros[-1])
# Out:
# Primeiro: 10
# Terceiro: 30
# Último: 50

# %%
# EXERCÍCIO 8 - TUPLAS (3)
aluno = ("Lucas", 20, "Informatica")
print("Nome:", aluno[0])
print("Idade:", aluno[1])
print("Curso:", aluno[2])
# Out:
# Nome: Lucas
# Idade: 20
# Curso: Informatica

# %%
# EXERCÍCIO 9 - TUPLAS (4)
cores = ("vermelho", "azul", "verde")
cores[1] = "amarelo"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2379/671844423.py in <cell line: 0>()
#       1 # EXERCÍCIO 9 - TUPLAS (4)
#       2 cores = ("vermelho", "azul", "verde")
# ----> 3 cores[1] = "amarelo"
#
# TypeError: 'tuple' object does not support item assignment

# %%
# EXERCÍCIO 10 - TUPLAS (5)
numeros = (2, 4, 2, 6, 2, 8, 10)
quantidade = numeros.count(2)
print("O número 2 aparece", quantidade, "vezes.")
# Out:
# O número 2 aparece 3 vezes.
