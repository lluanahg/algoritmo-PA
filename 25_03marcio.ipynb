# %% [markdown]
# <a href="https://colab.research.google.com/github/lluanahg/algoritmo-PA/blob/main/25_03marcio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Decisões

a = int (input("digitar um número: "))
b = int (input("digitar um número: "))

if a > b:
  print (f"{a} é maior que  {b}.")
else:
  print (f"{b} é maior que {a}.")
# Out:
# digitar um número: 9
# digitar um número: 10
# 10 é maior que 9.

# %%
# Escrever um programa que recebe 04 notas do aluno, calcula a média e mostra se o aluno foi aprovado.

# Entrada
print ("digite suas notas aqui, valores de 01 a 10]")
nota1 = float (input("digite a nota do 1 bimestre: "))
nota2 = float (input("digite a nota do 2 bimestre: "))
nota3 = float (input("digite a nota do 3 bimestre: "))
nota4 = float (input("digite a nota do 4 bimestre: "))

# Processamento

resultado = (nota1 + nota2 + nota3 + nota4) / 4

if resultado >= 7:
   print (f"A média das suas notas foi {resultado}, você foi aprovado. ")

elif resultado >= 5:
  print(f"A média da suas notas foi {resultado}, você terá que fazer recuperação.")

else:
     print(f"A média das suas notas foi {resultado}, você foi reprovado.")

     # Saída
# Out:
# digite suas notas aqui, valores de 01 a 10
# digite a nota do 1 bimestre: 5
# digite a nota do 2 bimestre: 8
# digite a nota do 3 bimestre: 9
# digite a nota do 4 bimestre: 7
# A média das suas notas foi 7.25, você foi aprovado.

# %%
# Fazer um,a calculadora simples com as 04 operações


print("-------------MENU-----------")
print("")
print (" Opcão - 1 = SOMA")
print(" Opção - 2 = SUBTRAÇÃO")
print (" Opção - 3 = MULTIPLICAÇÃO")
print (" Opção - 4 = DIVISÃO")
print("")

opcao = int (input("Digite a opção: "))

# Entrada

numero1 = float (input("Digite o primeiro número: "))
numero2 = float (input("Digite o segundo número: "))

#Processamento

if opcao == 1:
  resultado = numero1 + numero2
  print (f"O resultado é {resultado} ")

elif opcao == 2:
     resultado = numero1 - numero2
     print (f"O resultado é {resultado} ")

elif opcao == 3:
     resultado = numero1 * numero2
     print (f"O resultado é {resultado} ")

elif opcao == 4:
    if numero2 != 0:
     resultado = numero1 / numero2
     print (f"O resultado é {resultado} ")
    else:
      print (f"Erro: divisão por zero!")

else:
   print(f"Opção inválida!")
# Out:
# -------------MENU-----------
#
#  Opcão - 1 = SOMA
#  Opção - 2 = SUBTRAÇÃO
#  Opção - 3 = MULTIPLICAÇÃO
#  Opção - 4 = DIVISÃO
#
# Digite a opção: 2
# Digite o primeiro número: 2
# Digite o segundo número: 2
# O resultado é 0.0
