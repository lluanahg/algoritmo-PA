# %% [markdown]
# <a href="https://colab.research.google.com/github/lluanahg/algoritmo-PA/blob/main/codigo3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula de programação e ***algoritmos***

# %%
# Cálculo da area

# Entrada

lado_1 = 5

lado_2 = 4

nome = "marcio"

# %%
# Processamneto

area = lado_1*lado_2

# %%
# Saída

print (f"Total da área: {area}")
# Out:
# Total da área: 20

# %% [markdown]
# python

# %%
from contextlib import ExitStack
# Tipos Numéricos
idade = 25 # int
altura = 1.75 # float
numero_complexo = 2 + 3 #complex

# tipo texto
nome = "Alice"  # str


# tipo booleano

esta_chovendo = False # bool

# Tipo de lista ( Mutavel)
numeros = [1,2,3,4,5]  # list

# Tipo Tupla (imutavel)
coordenadas = ( 10, 20) # tuple

# Tipo de conjunto (valores unicos)
vogais = {'a','e', 'i', 'o', 'u'  } #set

#Tipo dicionario ( chave-valor)
pessoa = {"nome":"carlos" }
