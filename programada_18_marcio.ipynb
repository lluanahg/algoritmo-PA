# %% [markdown]
# <a href="https://colab.research.google.com/github/lluanahg/algoritmo-PA/blob/main/programada_18_marcio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Operadores arítiméticos

#Fazer u programa que o usuário digita 02 números.
#Saída mostrar operações aritíméticas.


#Entrada

a = int(input("digite um número: "))
b = int(input("digite um número: "))


#Processamento

soma = a + b
subtracao = a - b
multiplicacao = a * b
divisao = a / b
div_int = a // b
resto = a % b

#Saída

print("")
print("---------------------OPERADORESB ARITIMÉTICOS------------|")
print("                                                         |")
print("------------------------SOMA-----------------------------|")
print("                                                         |")
print(f"O resultado da SOMA de {a}  MAIS {b} é igual a : {soma}")
print("---------------------SUBTRAÇÃO---------------------------|")
print(f"O resultado da SUBTRAÇÃO de {a}   MENOS {b} é igual a : {subtracao} ")
print("")
print("---------------------multiplicaçao-----------------------|")
print("                                                         |")
print(f"O resultado da MULTIPLICAÇÃO de {a}  VEZES {b} é igual a : {multiplicacao}")
print("")
print("--------------------------------DIVISÃO------------------|")
print("                                                         |")
print(f"o resultado da DIVISÃO de {a} DIVIDIDO {b} é igual a : {divisao}")
print("")
print("---------------------DIVISÃO-----------------------|")
print("                                                         |")
print(f"O resultado da DIVISÃO INTEIRA de {a}  DIVIDIDO {b} é igual a : {div_int}")
print("")
print("                                                         |")
# Out:
# digite um número: 5
# digite um número: 6
#
# ---------------------OPERADORESB ARITIMÉTICOS------------|
#                                                          |
# ------------------------SOMA-----------------------------|
#                                                          |
# O resultado da SOMA de 5  MAIS 6 é igual a : 11
# ---------------------SUBTRAÇÃO---------------------------|
# O resultado da SUBTRAÇÃO de 5   MENOS 6 é igual a : -1
#
# ---------------------multiplicaçao-----------------------|
#                                                          |
# O resultado da MULTIPLICAÇÃO de 5  VEZES 6 é igual a : 30
#
# --------------------------------DIVISÃO------------------|
#                                                          |
# o resultado da DIVISÃO de 5 DIVIDIDO 6 é igual a : 0.8333333333333334
#
# ---------------------DIVISÃO-----------------------|
#                                                          |
# ...

# %%
#Entrada

horas = int(input("digite a quantidade de horas : "))


#Processamento

mi_int = horas * 60
se_int = horas * 3600

#Saída
print("Resultado")
print(f"Horas equivalem a {mi_int} minutos")
print(f"horas equivalem a  {se_int} segundos")
# Out:
# digite a quantidade de horas : 7
# Resultado
# Horas equivalem a 420 minutos
# horas equivalem a  25200 segundos

# %%
# Entrada

km = float(input("Digite a distancia em km"))

#Processanto

metros = km * 1000

#Saída
print("Resultado")
print(f"Km equivale a : {metros} metros ")
# Out:
# Digite a distancia em km7
# Resultado
# Km equivale a : 7000.0 metros
